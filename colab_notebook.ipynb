# %% [markdown]
# # 🎬 Sora Shutdown — Best Alternative: NexaAPI
#
# Sora shut down on March 24, 2026. This notebook shows you how to migrate to NexaAPI in minutes.
#
# **Get your free API key at [nexa-api.com](https://nexa-api.com) — no credit card required.**
#
# | Model | NexaAPI | Savings |
# |-------|---------|--------|
# | Kling 3.0 Pro | $0.0333/sec | 3x cheaper than Sora |
# | Sora 2 | $0.07/sec | 2.9x cheaper |
# | Veo 3 | $0.15/sec | 2.7x cheaper |

# %%
# !pip install nexaapi -q
print('✅ nexaapi installed — get your free key at https://nexa-api.com')

# %%
from nexaapi import NexaAPI

# Get your FREE API key at https://nexa-api.com (no credit card)
API_KEY = 'YOUR_FREE_API_KEY'
client = NexaAPI(api_key=API_KEY)

print('Client initialized! Ready to generate videos.')

# %%
# Generate a video with Kling 3.0 Pro (best Sora alternative)
response = client.video.generate(
    model='kling-3.0-pro',
    prompt='A serene mountain lake at golden hour, cinematic 4K, slow motion water ripples',
    duration=5,
    aspect_ratio='16:9'
)

print('✅ Video generated!')
print('URL:', response.video_url)
print('Cost: ~$0.17 for 5 seconds (3x cheaper than Sora was)')
